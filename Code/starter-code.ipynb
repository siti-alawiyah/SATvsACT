# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# As part of JustHangOn Consulting Group, we have been tasked by US Education department to provide recommendation on how might we be able to increase the SAT /ACT participate rate and score , so that the US education ranking system remain competitive and relevant globally.
#
# We will be studying the trends into the effect of individual key category in, and will provide key insights base on the following key category :
#
# States,
# Races,
# College Major,
# Household Income and State Income,
# Fee Waiver and Grant
#
# As part of the team undertaking this study, I will be analysing on College Major relation with participation rate and score

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# Datasets that was chosen for this project are: 2019 ACT Scores by State, 2019 SAT Scores by State, 2019 SAT Scores by Intended College Major, ACT Scores by Intended College Major ([*source*](https://www.act.org/content/dam/act/unsecured/documents/National-CCCR-2019.pdf))

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Besides choosing which colleges to apply and working towards the goal, it is equally important to choose a college major. Picking a college major will be one of the most important decisions that one will make as a student. Figuring out what path to focus on earlier in life, is a huge step to determine one's career path. There are many factors that contribute to choosing a college major. These factors include:
#
# Interest and Abilities
#
# Students will need to determine their own interests and abilities. They will need to know their strengths and weaknessess before pursuing their intended college major.
#
# Program Costs
#
# Students will need to research on the various program costs for the college major that they are interested in. College majors majoring in law ([*read more about this here*](https://www.collegeavestudentloans.com/blog/how-much-does-law-school-cost-average-law-degree-tuition-costs/#:~:text=According%20to%20U.S.%20News%2C%20the,over%20three%20years%20is%20%2484%2C792.)) or medicine have higher tuition fees ([*read more about this here*](https://www.collegeavestudentloans.com/blog/how-much-does-law-school-cost-average-law-degree-tuition-costs/#:~:text=According%20to%20U.S.%20News%2C%20the,over%20three%20years%20is%20%2484%2C792.)) compared to some other college majors in the USA. Hence, this will be one of the considering factor a student will have to consider as there might be some who will need to get student loans if they do decide to pursue in the major that they are interested in.
#
# Future Employability
#
# It is important to keep up with the world as well as to be able to see what skills or jobs that are in demand. Not all jobs have the same prospects. Some jobs are growing and will be in higher demand whereas some will lead to a declination.
#
# Income Potential
#
# To some, salary is one of the most important factor when choosing a career path. Hence, it is important to ask yourself if this matters to a student's lifestyle and responsibilites that one may have. Sometimes, income potential may not be a factor fro example to an art students who has a deep passion for art itself. ([*Income for different jobs*]

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code to calculate the mean   
def mean(data):
    n = len(data)
    mean = sum(data) / n
    return mean

# %%
mean([4, 8, 6, 5, 3, 2, 8, 9, 2, 5])
# Out:
# 5.2

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code for standard deviation
def variance(data):
    n = len(data)
    mean = sum(data) / n
    deviations = [(x - mean) ** 2 for x in data]
    variance = sum(deviations) / n
    return variance
 
def stddev(data):
    var = variance(data)
    std_dev = (var)**0.5
    return std_dev

# %%
stddev([4, 8, 6, 5, 3, 2, 8, 9, 2, 5])
# Out:
# 2.4

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code to convert percentage to float

def percent_to_float(s):
    s = str(float(s.rstrip("%")))
    i = s.find(".")
    if i == -1:
        return int(s) / 100
    if s.startswith("-"):
        return -percent_to_float(s.lstrip("-"))
    s = s.replace(".", "")
    i -= 2
    if i < 0:
        return float("." + "0" * abs(i) + s)
    else:
        return float(s[:i] + "." + s[i:])

# %%
percent_to_float('30.5%')
# Out:
# 0.305

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# Code to import different datas

sat_2019 = pd.read_csv('../data/sat_2019.csv')
act_2019 = pd.read_csv('../data/act_2019.csv')
sat_college_major_2019 = pd.read_csv('../data/sat_2019_by_intended_college_major.csv')
act_college_major_2019 = pd.read_csv('../data/act_2019_by_intended_college_major.csv')

# %%
print('ACT for 2019 is')
print(act_2019.head())

print('SAT for 2019 is')
print(sat_2019.head())

print('SAT by college major 2019 is')
print(sat_college_major_2019.head())

print('ACT by college major 2019 is')
print(act_college_major_2019.head())
# Out:
# ACT for 2019 is
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6
# SAT for 2019 is
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065
# SAT by college major 2019 is
#                                 IntendedCollegeMajor TestTakers Percent  \
# 0  Agriculture, AgricultureOperations, and Relate...     24,913      1%
# 1                  Architecture and Related Services     28,988      2%
# 2         Area, Ethnic, Cultural, and Gender Studies      2,629      0%
# ...

# %% [markdown]
# ### SAT 2019 Data Cleaning

# %%
#seeing the data info for SAT 2019
sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB

# %%
#finding the null vlaues in SAT 2019 Data
sat_2019.isnull().sum()
# Out:
# State                 0
# Participation Rate    0
# EBRW                  0
# Math                  0
# Total                 0
# dtype: int64

# %%
#seeing the columns for SAT 2019 Data
sat_2019.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
#changing the column names to lowercase letters
sat_2019.columns = sat_2019.columns.str.lower()

# %%
#replacing space in column names to underscore
sat_2019.columns = sat_2019.columns.str.replace(' ','_')

# %%
#finding the length of SAT 2019 data
len(sat_2019)
# Out:
# 53

# %%
#sort for values to see if there are any problems
sat_2019['participation_rate'].sort_values()
# Out:
# 12    100%
# 22    100%
# 5     100%
# 6     100%
# 7     100%
# 40    100%
# 9     100%
# 13    100%
# 31     18%
# 35     19%
# 34      2%
# 28     20%
# 36     22%
# 51      3%
# 27      3%
# 52      3%
# 24      3%
# 42      3%
# 15      3%
# 2      31%
# 16      4%
# 17      4%
# 45      4%
# 23      4%
# 25      4%
# 1      41%
# 18      5%
# 33     51%
# 37     51%
# 11     54%
# 3       6%
# 4      63%
# 14     66%
# 46     66%
# 44     68%
# 41     68%
# 48     68%
# 43      7%
# 0       7%
# 49     70%
# 38     70%
# 10     71%
# 32     79%
# 21     81%
# 30     82%
# 20     82%
# 26      9%
# 8      94%
# 29     95%
# 19     99%
# 50     99%
# 39       —
# 47       —
# Name: participation_rate, dtype: object

# %%
#dropping the rows that has -
sat_2019 = sat_2019.drop(labels=[39,47], axis=0)

# %%
#using function written above to convert percentage to float
sat_2019['participation_rate'] = sat_2019['participation_rate'].apply(percent_to_float)

# %%
#finding for duplicates
sat_2019.duplicated().value_counts()
# Out:
# False    51
# dtype: int64

# %%
sat_2019.head(1)
# Out:
#      state  participation_rate  ebrw  math  total
# 0  Alabama                0.07   583   560   1143

# %%
#changing the column names for sat 2019 data
new_column1 = ['state','participation_rate','ebrw','math','total_score' ]
sat_2019.columns = new_column1

# %%
sat_2019.head(1)
# Out:
#      state  participation_rate  ebrw  math  total_score
# 0  Alabama                0.07   583   560         1143

# %% [markdown]
# ### SAT Scores by Intended College Major 2019 Data cleaning

# %%
#looking at the info of the data
sat_college_major_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   IntendedCollegeMajor  38 non-null     object
#  1   TestTakers            38 non-null     object
#  2   Percent               38 non-null     object
#  3   Total                 38 non-null     int64
#  4   ReadingWriting        38 non-null     int64
#  5   Math                  38 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 1.9+ KB

# %%
#finding the null values in the data
sat_college_major_2019.isnull().sum()
# Out:
# IntendedCollegeMajor    0
# TestTakers              0
# Percent                 0
# Total                   0
# ReadingWriting          0
# Math                    0
# dtype: int64

# %%
#checking SAT College Major data
sat_college_major_2019.head()
# Out:
#                                 IntendedCollegeMajor TestTakers Percent  \
# 0  Agriculture, AgricultureOperations, and Relate...     24,913      1%
# 1                  Architecture and Related Services     28,988      2%
# 2         Area, Ethnic, Cultural, and Gender Studies      2,629      0%
# 3                 Biological and Biomedical Sciences    155,834      8%
# 4  Business, Management, Marketing, and Related S...    221,523     12%
#
#    Total  ReadingWriting  Math
# 0    977             496   481
# 1   1047             520   527
# 2   1040             536   504
# 3   1139             572   566
# 4   1072             534   537

# %%
#changing the column names to lowercase letters
sat_college_major_2019.columns = sat_college_major_2019.columns.str.lower()

# %%
#applying the function to change the percentage column to a float
sat_college_major_2019['percent'] = sat_college_major_2019['percent'].apply(percent_to_float)

# %%
#checking for percentage columns to see if there are any weird ones
sat_college_major_2019['percent'].unique()
# Out:
# array([0.01, 0.02, 0.  , 0.08, 0.12, 0.04, 0.11, 0.18, 0.07])

# %%
#changing the weird percentage to a proper float
sat_college_major_2019['percent'] = sat_college_major_2019['percent'].replace('0.  ',0.0)
sat_college_major_2019['percent'] = sat_college_major_2019['percent'].astype(float)

# %%
#checking the data info
sat_college_major_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   intendedcollegemajor  38 non-null     object
#  1   testtakers            38 non-null     object
#  2   percent               38 non-null     float64
#  3   total                 38 non-null     int64
#  4   readingwriting        38 non-null     int64
#  5   math                  38 non-null     int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 1.9+ KB

# %%
#changing the test takers from object to int
sat_college_major_2019['testtakers'] = sat_college_major_2019['testtakers'].str.replace(',','').astype(int)

# %%
#finding for duplicates
sat_college_major_2019.duplicated().value_counts()
# Out:
# False    38
# dtype: int64

# %%
#changing column names for SAT 2019
new_columns = ['intendedcollegemajor','testtakers','participation_rate','total_score','ebrw','math' ]
sat_college_major_2019.columns = new_columns

# %%
#re-checking SAT College Major data
sat_college_major_2019.head()
# Out:
#                                 intendedcollegemajor  testtakers  \
# 0  Agriculture, AgricultureOperations, and Relate...       24913
# 1                  Architecture and Related Services       28988
# 2         Area, Ethnic, Cultural, and Gender Studies        2629
# 3                 Biological and Biomedical Sciences      155834
# 4  Business, Management, Marketing, and Related S...      221523
#
#    participation_rate  total_score  ebrw  math
# 0                0.01          977   496   481
# 1                0.02         1047   520   527
# 2                0.00         1040   536   504
# 3                0.08         1139   572   566
# 4                0.12         1072   534   537

# %% [markdown]
# ### ACT Scores by Intended College Major 2019 Data cleaning

# %%
#looking at the info of the data
act_college_major_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   IntendedCollegeMajor  38 non-null     object
#  1   TestTakers            17 non-null     object
#  2   Percent               17 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.0+ KB

# %%
#finding the null values in the data
act_college_major_2019.isnull().sum()
# Out:
# IntendedCollegeMajor     0
# TestTakers              21
# Percent                 21
# dtype: int64

# %%
act_college_major_2019.dropna(inplace = True)

# %%
#finding the null values in the data
act_college_major_2019.isnull().sum()
# Out:
# IntendedCollegeMajor    0
# TestTakers              0
# Percent                 0
# dtype: int64

# %%
act_college_major_2019.shape
# Out:
# (17, 3)

# %%
#checking ACT College Major data
act_college_major_2019.head()
# Out:
#                                 IntendedCollegeMajor TestTakers  Percent
# 0  Agriculture, AgricultureOperations, and Relate...     21,781      1.0
# 1                  Architecture and Related Services     15,422      1.0
# 2         Area, Ethnic, Cultural, and Gender Studies      1,761      0.0
# 4  Business, Management, Marketing, and Related S...    125,457      8.0
# 5    Communication, Journalism, and Related Programs     18,532      1.0

# %%
#changing the column names to lowercase letters
act_college_major_2019.columns = act_college_major_2019.columns.str.lower()

# %%
#checking the data info
act_college_major_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17 entries, 0 to 37
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   intendedcollegemajor  17 non-null     object
#  1   testtakers            17 non-null     object
#  2   percent               17 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 544.0+ bytes

# %%
#changing the test takers from object to int
act_college_major_2019['testtakers'] = act_college_major_2019['testtakers'].str.replace(',','').astype(int)

# %%
#changing column names for ACT 2019
new_columns = ['intendedcollegemajor','testtakers','participation_rate' ]
act_college_major_2019.columns = new_columns

# %%
#checking ACT College Major data
act_college_major_2019.head()
# Out:
#                                 intendedcollegemajor  testtakers  \
# 0  Agriculture, AgricultureOperations, and Relate...       21781
# 1                  Architecture and Related Services       15422
# 2         Area, Ethnic, Cultural, and Gender Studies        1761
# 4  Business, Management, Marketing, and Related S...      125457
# 5    Communication, Journalism, and Related Programs       18532
#
#    participation_rate
# 0                 1.0
# 1                 1.0
# 2                 0.0
# 4                 8.0
# 5                 1.0

# %% [markdown]
# ### ACT 2019 Data Cleaning

# %%
#Looking at the info of ACT data
act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
#finding the null values in ACT data
act_2019.isnull().sum()
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %%
#checking ACT column
act_2019.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
#Checking if got any weird participation percentage
act_2019['Participation'].unique()
# Out:
# array(['100%', '38%', '73%', '23%', '27%', '22%', '13%', '32%', '54%',
#        '49%', '80%', '31%', '35%', '29%', '66%', '72%', '6%', '28%',
#        '21%', '19%', '95%', '82%', '14%', '25%', '63%', '96%', '42%',
#        '17%', '12%', '78%', '75%', '39%', '20%', '24%', '52%'],
#       dtype=object)

# %%
#using the function above to change the percentage to a float
act_2019['Participation'] = act_2019['Participation'].apply(percent_to_float)

# %%
#re-checking the ACT info
act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   Composite      52 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB

# %%
#finding for duplicates
act_2019.duplicated().value_counts()
# Out:
# False    52
# dtype: int64

# %%
#changing the column names to lowecase letters
act_2019.columns = act_2019.columns.str.lower()

# %%
new_columns = ['state','participation_rate','composite_score']
act_2019.columns = new_columns

# %%
#checking ACT column
act_2019.head()
# Out:
#         state  participation_rate  composite_score
# 0     Alabama                1.00             18.9
# 1      Alaska                0.38             20.1
# 2     Arizona                0.73             19.0
# 3    Arkansas                1.00             19.3
# 4  California                0.23             22.6

# %% [markdown]
# ### Finding the difference of state in ACT 2019 and SAT 2019 Data

# %%
a = set(act_2019["state"].unique())
b = set(sat_2019["state"].unique())

# %%
print(a.difference(b))
# Out:
# {'National'}

# %%
act_2019['state']
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
act_2019.loc[act_2019['state'] == 'National']
# Out:
#        state  participation_rate  composite_score
# 51  National                0.52             20.7

# %%
#dropping National from the data
act_2019.drop([51],inplace = True)

# %%
#checking the state column
act_2019['state']
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**intendedcollegemajor**|*object*|sat_college_major_2019|Different college majors|
# |**testtakers**|*int*|sat_college_major_2019|Number of test takers per college major in 2019|
# |**participation_rate**|*float*|sat_college_major_2019|Percentage of test takers per college major in 2019 where 1.0 represents 100%|
# |**total_score**|*int*|sat_college_major_2019|Total score: Math+ReadingWriting|
# |**ebrw**|*int*|sat_college_major_2019|Mean score of evidence based reading and writing per intended college major|
# |**math**|*int*|sat_college_major_2019|Mean score of mathematics per intended college major|
# |**state**|*object*|act_2019|Different states in US|
# |**participation_rate**|*float*|act_2019|State percentages were calculated by ACT based on the number of high school graduates in each state as projected by the Western Interstate Commission for Higher Education (WICHE) where 1.0 = 100%|
# |**total_score**|*float*|act_2019|Composite score is number of correct answers converts to a score that ranges from 1 to 36 for each of the four tests—and composite score is the average of those. |
# |**state**|*object*|sat_2019|Different states in US|
# |**participation_rate**|*int*|sat_2019|Percentage of test takers taking SAT in 2019, 1.0 = 100%|
# |**ebrw**|*int*|sat_2019|Mean score of evidence based reading and writing|
# |**math**|*int*|sat_2019|Mean score of mathematics|
# |**total_score**|*int*|sat_2019|Total mean score of SAT|
# |**intendedcollegemajor**|*object*|act_college_major_2019|Different college majors|
# |**testtakers**|*int*|act_college_major_2019|Number of test takers per college major in 2019|
# |**participation_rate**|*float*|act_college_major_2019|Percentage of test takers per college major in 2019 where 1.0 represents 100%|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ### Overall Summary Statistics

# %%
sat_2019.describe()
# Out:
#        participation_rate        ebrw        math  total_score
# count           51.000000   51.000000   51.000000    51.000000
# mean             0.490588  560.803922  552.196078  1113.078431
# std              0.387476   46.248035   51.290553    97.197910
# min              0.020000  483.000000  460.000000   943.000000
# 25%              0.055000  527.500000  511.500000  1038.000000
# 50%              0.540000  550.000000  546.000000  1097.000000
# 75%              0.820000  612.000000  599.000000  1210.000000
# max              1.000000  636.000000  648.000000  1284.000000

# %% [markdown]
# Mean participation rate for SAT 2019: 49.06%
#
# Mean score of EBRW for SAT 2019: 560.80
#
# Mean score of Math for SAT 2019: 552.20
#
# Mean total score for SAT 2019: 1113.08

# %%
act_2019.describe()
# Out:
#        participation_rate  composite_score
# count           51.000000        51.000000
# mean             0.586667        21.464706
# std              0.345159         2.194523
# min              0.060000        17.900000
# 25%              0.245000        19.800000
# 50%              0.540000        21.100000
# 75%              1.000000        23.700000
# max              1.000000        25.500000

# %% [markdown]
# Mean participation rate for ACT 2019: 58.67%
#
# Mean composite score for ACT 2019: 21.46

# %%
sat_college_major_2019.describe()
# Out:
#           testtakers  participation_rate  total_score        ebrw        math
# count      38.000000           38.000000    38.000000   38.000000   38.000000
# mean    48394.500000            0.025789  1058.500000  535.500000  523.000000
# std     72753.092558            0.039975    82.445969   41.362439   43.386385
# min       283.000000            0.000000   916.000000  458.000000  456.000000
# 25%      6611.000000            0.000000   988.250000  501.250000  486.500000
# 50%     16370.500000            0.010000  1066.500000  537.000000  527.000000
# 75%     60215.750000            0.035000  1115.500000  569.750000  542.250000
# max    331026.000000            0.180000  1242.000000  597.000000  646.000000

# %% [markdown]
# Mean participation rate for SAT 2019 by Intended College Major: 2.56%
#
# Mean score of EBRW for SAT 2019 by Intended College Major: 535.50
#
# Mean score of Math for SAT 2019 by Intended College Major: 523.00
#
# Mean total score for SAT 2019 by Intended College Major: 1058.50

# %%
act_college_major_2019.describe()
# Out:
#           testtakers  participation_rate
# count      17.000000                17.0
# mean    65657.705882                 4.0
# std     66132.388499                 4.0
# min      1761.000000                 0.0
# 25%     16846.000000                 1.0
# 50%     46344.000000                 3.0
# 75%     97984.000000                 6.0
# max    218316.000000                13.0

# %% [markdown]
# Mean participation rate for ACT 2019 by Intended College Major: 4.0%

# %% [markdown]
# ### Using dictionary comprehension to apply standard deviation function created in a function, in the earlier part of the notebook

# %%
#ACT 2019 Data
act_participation_stddev = stddev(act_2019['participation_rate'])
act_composite_score_stddev = stddev(act_2019['composite_score'])

# %%
#SAT 2019 Data
sat_participation_stddev = stddev(sat_2019['participation_rate'])
sat_ebrw_stddev = stddev(sat_2019['ebrw'])
sat_math_stddev = stddev(sat_2019['math'])
sat_total_score_stddev = stddev(sat_2019['total_score'])

# %%
#SAT Scores by Intended College Major
satcollegemajor_testtakers_stddev = stddev(sat_college_major_2019['testtakers'])
satcollegemajor_participation_stddev = stddev(sat_college_major_2019['participation_rate'])
satcollegemajor_total_score_stddev = stddev(sat_college_major_2019['total_score'])
satcollegemajor_ebrw_stddev = stddev(sat_college_major_2019['ebrw'])
satcollegemajor_math_stddev = stddev(sat_college_major_2019['math'])

# %%
#ACT Scores by Intended College Major
actcollegemajor_testtakers_stddev = stddev(sat_college_major_2019['testtakers'])
actcollegemajor_participation_stddev = stddev(sat_college_major_2019['participation_rate'])

# %%
std = {'SAT': {'Participation':sat_participation_stddev,
               'EBRW':sat_ebrw_stddev,
               'Math':sat_math_stddev,
               'TotalScore':sat_total_score_stddev},
      'ACT':{'Participation':act_participation_stddev,
              'Composite':act_composite_score_stddev},
       'SAT_Collegemajor':{'Testtakers':satcollegemajor_testtakers_stddev,
              'Participation':satcollegemajor_participation_stddev,
              'TotalScore':satcollegemajor_total_score_stddev,
              'EBRW':satcollegemajor_ebrw_stddev,
              'Math':satcollegemajor_math_stddev},
       'ACT_Collegemajor':{'Testtakers':actcollegemajor_testtakers_stddev,
              'Participation':actcollegemajor_participation_stddev}}

# %%
std['SAT']
# Out:
# {'Participation': 0.3836584048685726,
#  'EBRW': 45.792378682545134,
#  'Math': 50.78521461840036,
#  'TotalScore': 96.24027185617864}

# %%
std['ACT']
# Out:
# {'Participation': 0.3417582373703047, 'Composite': 2.172901153595978}

# %%
std['SAT_Collegemajor']
# Out:
# {'Testtakers': 71789.43289002257,
#  'Participation': 0.03944560404747735,
#  'TotalScore': 81.35392139482761,
#  'EBRW': 40.814567832679806,
#  'Math': 42.811705236572365}

# %%
std['ACT_Collegemajor']
# Out:
# {'Testtakers': 71789.43289002257, 'Participation': 0.03944560404747735}

# %% [markdown]
# ### Investigating SAT 2019 Data

# %%
#Top 10 states that has the highest participation rate in SAT 2019
sat_2019.sort_values(['participation_rate'],ascending = False).head(10)
# Out:
#             state  participation_rate  ebrw  math  total_score
# 40   Rhode Island                1.00   503   492          995
# 13       Illinois                1.00   509   504         1013
# 22       Michigan                1.00   507   496         1003
# 5        Colorado                1.00   518   506         1024
# 6     Connecticut                1.00   529   516         1046
# 7        Delaware                1.00   499   486          985
# 9         Florida                1.00   516   483          999
# 12          Idaho                1.00   505   488          993
# 19          Maine                0.99   512   502         1013
# 50  West Virginia                0.99   483   460          943

# %%
#Bottom 10 states that has the lowest participation rate for SAT 2019
sat_2019.sort_values(['participation_rate'],ascending = True).head(10)
# Out:
#            state  participation_rate  ebrw  math  total_score
# 34  North Dakota                0.02   627   636         1263
# 52       Wyoming                0.03   623   615         1238
# 42  South Dakota                0.03   633   635         1268
# 27      Nebraska                0.03   628   631         1260
# 51     Wisconsin                0.03   635   648         1283
# 24   Mississippi                0.03   628   608         1237
# 15          Iowa                0.03   622   622         1244
# 45          Utah                0.04   614   615         1230
# 23     Minnesota                0.04   636   648         1284
# 17      Kentucky                0.04   620   612         1232

# %%
#States that has 50% or more participation rate for SAT
sat_2019[sat_2019['participation_rate'] > 0.5]
# Out:
#                    state  participation_rate  ebrw  math  total_score
# 4             California                0.63   534   531         1065
# 5               Colorado                1.00   518   506         1024
# 6            Connecticut                1.00   529   516         1046
# 7               Delaware                1.00   499   486          985
# 8   District of Columbia                0.94   495   480          975
# 9                Florida                1.00   516   483          999
# 10               Georgia                0.71   538   519         1058
# 11                Hawaii                0.54   550   550         1100
# 12                 Idaho                1.00   505   488          993
# 13              Illinois                1.00   509   504         1013
# 14               Indiana                0.66   543   537         1080
# 19                 Maine                0.99   512   502         1013
# ...

# %% [markdown]
# In total, there are about 20 states that who are contracted with the College Board to administer SAT to some or all high school juniors for free. Hence from the above data, states who have done so will have 1.0 or high participation rate.
# States such as Alaska, Arkansas, Arizona, Florida, Georgia, Kentucky, Maryland, Minnesota , Mississippi, New Mexico, New York, Oregon, Virginia, Texas, and Washington gave their students as an option or requirement. With this in place, the states still have at least 50% participation rate for SAT.
# ([*Link to the states that made contract with the College Board to administer SAT*](https://blog.prepscholar.com/which-states-require-the-sat))

# %%
#Top 10 States that has the highest mean total score
sat_2019.sort_values(['total_score'],ascending = False).head(10)
# Out:
#            state  participation_rate  ebrw  math  total_score
# 23     Minnesota                0.04   636   648         1284
# 51     Wisconsin                0.03   635   648         1283
# 42  South Dakota                0.03   633   635         1268
# 34  North Dakota                0.02   627   636         1263
# 27      Nebraska                0.03   628   631         1260
# 15          Iowa                0.03   622   622         1244
# 16        Kansas                0.04   618   623         1241
# 52       Wyoming                0.03   623   615         1238
# 24   Mississippi                0.03   628   608         1237
# 25      Missouri                0.04   622   615         1236

# %% [markdown]
# From the above table, Minnesota, Wisconsin and Dakota has the highest total mean score. However, the SAT participation rate for the mentioned states are extremely low indicating that there is a possibility that only their top students participated in the SAT test.

# %%
#Bottom 10 States that has the lowest mean total score
sat_2019.sort_values(['total_score'],ascending = True).head(10)
# Out:
#                    state  participation_rate  ebrw  math  total_score
# 50         West Virginia                0.99   483   460          943
# 36              Oklahoma                0.22   490   472          963
# 8   District of Columbia                0.94   495   480          975
# 7               Delaware                1.00   499   486          985
# 12                 Idaho                1.00   505   488          993
# 40          Rhode Island                1.00   503   492          995
# 9                Florida                1.00   516   483          999
# 22              Michigan                1.00   507   496         1003
# 19                 Maine                0.99   512   502         1013
# 13              Illinois                1.00   509   504         1013

# %% [markdown]
# The states in the above table has the lowest mean total score. Majority of these states have high participation rate, indicating that all/ majority of their students participated in the SAT, regardless if the students are able to perform well in the SAT. However, it does not mean that the states are not doing well as their mean total score fall slightly short of the national average which can be seen from overall summary statistics of SAT data.

# %% [markdown]
# ### Investigating ACT 2019 Data

# %%
#Top 10 participation rate for ACT 2019
act_2019.sort_values(['participation_rate'],ascending=False).head(10)
# Out:
#              state  participation_rate  composite_score
# 0          Alabama                 1.0             18.9
# 17        Kentucky                 1.0             19.8
# 49       Wisconsin                 1.0             20.3
# 44            Utah                 1.0             20.3
# 42       Tennessee                 1.0             19.4
# 36        Oklahoma                 1.0             18.9
# 35            Ohio                 1.0             20.0
# 33  North Carolina                 1.0             19.0
# 28          Nevada                 1.0             17.9
# 27        Nebraska                 1.0             20.0

# %%
#Bottom 10 participation rate for ACT 2019
act_2019.sort_values(['participation_rate'],ascending=True).head(10)
# Out:
#             state  participation_rate  composite_score
# 19          Maine                0.06             24.3
# 39   Rhode Island                0.12             24.7
# 7        Delaware                0.13             24.1
# 29  New Hampshire                0.14             25.0
# 38   Pennsylvania                0.17             23.6
# 22       Michigan                0.19             24.4
# 45        Vermont                0.20             24.1
# 46       Virginia                0.21             24.0
# 21  Massachusetts                0.21             25.5
# 32       New York                0.22             24.5

# %%
#States that has 50% or more participation rate for ACT
act_2019[act_2019['participation_rate'] > 0.5]
# Out:
#              state  participation_rate  composite_score
# 0          Alabama                1.00             18.9
# 2          Arizona                0.73             19.0
# 3         Arkansas                1.00             19.3
# 9          Florida                0.54             20.1
# 11          Hawaii                0.80             19.0
# 15            Iowa                0.66             21.6
# 16          Kansas                0.72             21.2
# 17        Kentucky                1.00             19.8
# 18       Louisiana                1.00             18.8
# 23       Minnesota                0.95             21.4
# 24     Mississippi                1.00             18.4
# 25        Missouri                0.82             20.8
# 26         Montana                1.00             19.8
# 27        Nebraska                1.00             20.0
# 28          Nevada                1.00             17.9
# 31      New Mexico                0.63             19.3
# ...

# %% [markdown]
# In total, there are about 18 states that who are contracted to administer ACT to some or all high school juniors for free. Hence from the above data, states who have done so will have 1.0 or high participation rate.States that have low participation rate for ACT is due to the state having a preferential to SAT instead.
# ([*Links to states that offer ACT*](https://blog.prepscholar.com/which-states-require-the-act-full-list-and-advice))

# %%
#Top 10 States that has the highest mean total composite score
act_2019.sort_values(['composite_score'],ascending = False).head(10)
# Out:
#             state  participation_rate  composite_score
# 21  Massachusetts                0.21             25.5
# 6     Connecticut                0.22             25.5
# 29  New Hampshire                0.14             25.0
# 39   Rhode Island                0.12             24.7
# 32       New York                0.22             24.5
# 22       Michigan                0.19             24.4
# 19          Maine                0.06             24.3
# 13       Illinois                0.35             24.3
# 30     New Jersey                0.25             24.2
# 45        Vermont                0.20             24.1

# %%
#Bottom 10 States that has the lowest mean total composite score
act_2019.sort_values(['composite_score'],ascending = True).head(10)
# Out:
#              state  participation_rate  composite_score
# 28          Nevada                1.00             17.9
# 24     Mississippi                1.00             18.4
# 40  South Carolina                0.78             18.8
# 18       Louisiana                1.00             18.8
# 0          Alabama                1.00             18.9
# 36        Oklahoma                1.00             18.9
# 2          Arizona                0.73             19.0
# 33  North Carolina                1.00             19.0
# 11          Hawaii                0.80             19.0
# 3         Arkansas                1.00             19.3

# %% [markdown]
# From the above 2 tables, the states (such as Massachusetts, Connecticut,New Hampshire) that have high mean composite scores have the lowest participation rate for ACT. The ACT participation rate for the mentioned states are extremely low indicating that there is a possibility that only some of their top students participated in the ACT test. Also, these states have higher participation rate for SAT comapred to ACT as seen in the table for SAT 2019 data. This was also seen from comparing their composite score to the state wide mean composite score.
#
# Also, the states that has the lowest mean composite score has the highest participation rate, indicating that majority or almost all of their students participated in the ACT regardless if the student can perform well in the ACT.

# %% [markdown]
# ### Investigating SAT results by intended college major data

# %%
# Top 10 SAT participation rate by intended college major in 2019
sat_college_major_2019.sort_values(by=['testtakers'],ascending=[False]).head(10)
# Out:
#                                  intendedcollegemajor  testtakers  \
# 14   Health Professions and related Clinical Sciences      331026
# 4   Business, Management, Marketing, and Related S...      221523
# 9                                         Engineering      194127
# 3                  Biological and Biomedical Sciences      155834
# 35                Visual and Performing Arts, General      130642
# 37                                          Undecided      126939
# 6   Computer and Information Sciences and Support ...       79736
# 29                                Psychology, General       75626
# 8                                           Education       71882
# 31                   Security and Protective Services       68177
#
#     participation_rate  total_score  ebrw  math
# 14                0.18         1048   529   518
# 4                 0.12         1072   534   537
# 9                 0.11         1139   559   581
# ...

# %%
# Bottom 10 SAT participation rate by intended college major in 2019
sat_college_major_2019.sort_values(by=['testtakers'],ascending=[True]).head(10)
# Out:
#                             intendedcollegemajor  testtakers  \
# 18                 Library Science/Librarianship         283
# 28                          Precision Production         319
# 34           Transportation and Materials Moving        1105
# 33              Theology and Religious Vocations        1991
# 7                   Construction Trades, General        2500
# 2     Area, Ethnic, Cultural, and Gender Studies        2629
# 22               Multi/Interdisciplinary Studies        2979
# 26              Philosophy and Religious Studies        3381
# 12   Family and Consumer Sciences/Human Sciences        6469
# 20  Mechanic and Repair Technologies/Technicians        6592
#
#     participation_rate  total_score  ebrw  math
# 18                 0.0         1105   577   527
# 28                 0.0          932   466   466
# 34                 0.0         1019   511   508
# 33                 0.0         1096   561   535
# 7                  0.0          919   459   460
# ...

# %%
#Top 10 of total score by intended college major in 2019
sat_college_major_2019.sort_values(by=['total_score'],ascending=[False]).head(10)
# Out:
#                                  intendedcollegemajor  testtakers  \
# 19                         Mathematics and Statistics       16508
# 27                                  Physical Sciences       26318
# 32                                    Social Sciences       33356
# 6   Computer and Information Sciences and Support ...       79736
# 22                    Multi/Interdisciplinary Studies        2979
# 17  Liberal Arts and Sciences, General Studies and...        8611
# 3                  Biological and Biomedical Sciences      155834
# 9                                         Engineering      194127
# 26                   Philosophy and Religious Studies        3381
# 11            English Language and Literature/Letters       16233
#
#     participation_rate  total_score  ebrw  math
# 19                0.01         1242   597   646
# 27                0.01         1203   597   606
# 32                0.02         1164   594   570
# ...

# %%
#Bottom 10 of total score by intended college major in 2019
sat_college_major_2019.sort_values(by=['total_score'],ascending=[True]).head(10)
# Out:
#                                  intendedcollegemajor  testtakers  \
# 20       Mechanic and Repair Technologies/Technicians        6592
# 7                        Construction Trades, General        2500
# 25            Personal and Culinary Services, General        6668
# 28                               Precision Production         319
# 12        Family and Consumer Sciences/Human Sciences        6469
# 24              Parks, Recreation and Leisure Studies       13039
# 36                                              Other       26888
# 31                   Security and Protective Services       68177
# 0   Agriculture, AgricultureOperations, and Relate...       24913
# 21                              Military Technologies        7448
#
#     participation_rate  total_score  ebrw  math
# 20                0.00          916   458   458
# 7                 0.00          919   459   460
# 25                0.00          929   474   456
# ...

# %% [markdown]
# From the above findings, it can be seen that these are the unpopular college major in the country. This is due to the low mean hourly wage from the above jobs. For example, technicians median wage is USD46,760  ([*source*](https://www.bls.gov/oes/current/oes493023.htm)). Comparing it with general construction trades that pays about USD36 860 ([*source*](https://money.usnews.com/careers/best-jobs/construction-worker/salary)). Also, the jobs listed above does not really require a potential worker to have a college degree due to the nature of the job scope.

# %% [markdown]
# ### Investigating ACT results by intended college major data

# %%
# Top 10 ACT participation rate by intended college major in 2019
act_college_major_2019.sort_values(by=['testtakers'],ascending=[False]).head(10)
# Out:
#                                  intendedcollegemajor  testtakers  \
# 14   Health Professions and related Clinical Sciences      218316
# 37                                          Undecided      198909
# 4   Business, Management, Marketing, and Related S...      125457
# 9                                         Engineering      104204
# 27                                  Physical Sciences       97984
# 32                                    Social Sciences       92008
# 35                Visual and Performing Arts, General       67693
# 8                                           Education       49559
# 6   Computer and Information Sciences and Support ...       46344
# 12        Family and Consumer Sciences/Human Sciences       26618
#
#     participation_rate
# 14                13.0
# 37                12.0
# 4                  8.0
# 9                  6.0
# 27                 6.0
# 32                 6.0
# 35                 4.0
# 8                  3.0
# ...

# %%
# Bottom 10 ACT participation rate by intended college major in 2019
act_college_major_2019.sort_values(by=['testtakers'],ascending=[True]).head(10)
# Out:
#                                  intendedcollegemajor  testtakers  \
# 2          Area, Ethnic, Cultural, and Gender Studies        1761
# 33                   Theology and Religious Vocations        3852
# 11            English Language and Literature/Letters       10895
# 1                   Architecture and Related Services       15422
# 10               Engineering Technologies/Technicians       16846
# 5     Communication, Journalism, and Related Programs       18532
# 0   Agriculture, AgricultureOperations, and Relate...       21781
# 12        Family and Consumer Sciences/Human Sciences       26618
# 6   Computer and Information Sciences and Support ...       46344
# 8                                           Education       49559
#
#     participation_rate
# 2                  0.0
# 33                 0.0
# 11                 1.0
# 1                  1.0
# 10                 1.0
# 5                  1.0
# 0                  1.0
# 12                 2.0
# ...

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# ### Heat map correlation for ACT 2019

# %%
# Establish size of figure.
plt.figure(figsize = (16,9))

# Get correlation of variables.
corr = act_2019.corr()

# Set up mask to be "True" in the upper triangle.
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

# Plot our correlation heatmap, while masking the upper triangle to be white.
with sns.axes_style("white"):
    sns.heatmap(corr, mask = mask, square = True, annot = True, vmin = -1, vmax = 1, linewidths = .5)

# %% [markdown]
# ### Heat Map Correlation for SAT 2019

# %%
# Establish size of figure.
plt.figure(figsize = (16,9))

# Get correlation of variables.
corr = sat_2019.corr()

# Set up mask to be "True" in the upper triangle.
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

# Plot our correlation heatmap, while masking the upper triangle to be white.
with sns.axes_style("white"):
    sns.heatmap(corr, mask = mask, square = True, annot = True, vmin = -1, vmax = 1, linewidths = .5)

# %% [markdown]
# ### Heat Map correlation for SAT 2019 data by Intended College Major

# %%
# Establish size of figure.
plt.figure(figsize = (16,9))

# Get correlation of variables.
corr = sat_college_major_2019.corr()

# Set up mask to be "True" in the upper triangle.
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

# Plot our correlation heatmap, while masking the upper triangle to be white.
with sns.axes_style("white"):
    sns.heatmap(corr, mask = mask, square = True, annot = True, vmin = -1, vmax = 1, linewidths = .5)

# %%
# Establish size of figure.
plt.figure(figsize = (16,9))

# Get correlation of variables.
corr = act_college_major_2019.corr()

# Set up mask to be "True" in the upper triangle.
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

# Plot our correlation heatmap, while masking the upper triangle to be white.
with sns.axes_style("white"):
    sns.heatmap(corr, mask = mask, square = True, annot = True, vmin = -1, vmax = 1, linewidths = .5)

# %% [markdown]
# ### Plotting SAT Participation Rate over the States

# %%
sat_2019.hist(column='participation_rate', xlabelsize=30, ylabelsize=30, figsize=(20,10), bins=20)[0:50]
plt.xlabel('SAT Participation Rate', fontsize=20)
plt.ylabel('Number of States', fontsize=20)
plt.title('SAT Participation Across the States')
plt.show;

# %% [markdown]
# ### Plotting ACT Participation Rate over the States

# %%
act_2019.hist(column='participation_rate', xlabelsize=30, ylabelsize=30, figsize=(20,10), bins=20)[0:50]
plt.xlabel('ACT Participation Rate', fontsize=20)
plt.ylabel('Number of States', fontsize=20)
plt.title('ACT Participation Across the States')
plt.show;

# %% [markdown]
# ### Plotting the SAT participation over the Intended College Major

# %%
sat_college_major_2019.hist(column='participation_rate', xlabelsize=30, ylabelsize=30, figsize=(20,10), bins=20)[0:50]
plt.xlabel('SAT Participation Rate', fontsize=20)
plt.ylabel('Intended College Major', fontsize=20)
plt.title('SAT Participation over Intended College Major')
plt.show;

# %%
act_college_major_2019.hist(column='participation_rate', xlabelsize=30, ylabelsize=30, figsize=(20,10), bins=20)[0:50]
plt.xlabel('ACT Participation Rate', fontsize=20)
plt.ylabel('Intended College Major', fontsize=20)
plt.title('ACT Participation over Intended College Major')
plt.show;

# %% [markdown]
# ### Combining the participation rate over the 3 datasets in 1 graph

# %%
# Establish figure size.
plt.figure(figsize = (16,9))

# We can create subplots, which allows us to have multiple subplots in the same plot.
# plt.subplot(3, 1, 1) means we have 3 rows, 1 column, and are referencing plot 1.
ax1 = plt.subplot(3, 1, 1)
ax1.set_title('SAT Participation Rate')
ax1.hist(sat_2019['participation_rate']);
plt.tight_layout()
plt.tight_layout()

# plt.subplot(3, 1, 2) means we have 3 rows, 1 column, and are referencing plot 2.
ax2 = plt.subplot(3, 1, 2, sharex = ax1)
ax2.set_title('ACT Participation Rate')
ax2.hist(act_2019['participation_rate']);
plt.tight_layout()
plt.tight_layout()

# plt.subplot(3, 1, 3) means we have 3 rows, 1 column, and are referencing plot 3.
ax3 = plt.subplot(3, 1, 3, sharex = ax2)
ax3.set_title('SAT participation rate by Intended College Major')
ax3.hist(sat_college_major_2019['participation_rate']);

# plt.tight_layout() # adds more space

# %% [markdown]
# ### Plotting boxplots for different datasets

# %%
plt.boxplot(sat_2019['total_score'][0:50],vert=False, whis=10.0, autorange=True)
plt.xlabel('Total SAT Scores')
plt.title('Total SAT Scores Boxplot')
plt.show;

# %%
plt.boxplot(act_2019['composite_score'][0:50],vert=False, whis=10.0, autorange=True)
plt.xlabel('Total ACT Scores')
plt.title('Total ACT Scores Boxplot')
plt.show;

# %%
plt.boxplot(sat_college_major_2019['total_score'][0:50],vert=False, whis=10.0, autorange=True)
plt.xlabel('Total SAT Scores by Intended College Major')
plt.title('Total SAT Scores by Intended College Major Boxplot')
plt.show;

# %%
plt.boxplot(sat_2019['participation_rate'][0:50],vert=False, whis=10.0, autorange=True)
plt.xlabel('SAT Participation Rate')
plt.title('SAT Participation Rate Boxplot')
plt.show;

# %%
plt.boxplot(act_2019['participation_rate'][0:50],vert=False, whis=10.0, autorange=True)
plt.xlabel('ACT Participation Rate')
plt.title('ACT Participation Rate Boxplot')
plt.show;

# %%
plt.boxplot(sat_college_major_2019['participation_rate'][0:50],vert=False, whis=10.0, autorange=True)
plt.xlabel('SAT Participation Rate by Intended College Major ')
plt.title('SAT Participation Rate by Intended College Major Boxplot')
plt.show;

# %%
plt.boxplot(act_college_major_2019['participation_rate'][0:50],vert=False, whis=10.0, autorange=True)
plt.xlabel('ACT Participation Rate by Intended College Major ')
plt.title('ACT Participation Rate by Intended College Major Boxplot')
plt.show;

# %% [markdown]
# ### Plotting scatter plots for different datasets

# %%
# Establish the size of the figure.
plt.figure(figsize = (16, 9))

# Create scatterplot of total score vs composite score
plt.scatter(sat_2019['total_score'],
            act_2019['composite_score']);

plt.title("SAT Total Score VS ACT Composite Score")
plt.ylabel("ACT Composite Score", fontsize = 20)
plt.xlabel("SAT Total Score", fontsize = 20);

# %%
#finding correlation between SAT total score and ACT Composite score
np.corrcoef(sat_2019['total_score'],act_2019['composite_score'])
# Out:
# array([[ 1.        , -0.42478152],
#        [-0.42478152,  1.        ]])

# %%
# Establish the size of the figure.
plt.figure(figsize = (16, 9))

# Create scatterplot of sat participation vs act participation
plt.scatter(sat_2019['participation_rate'],
            act_2019['participation_rate']);

plt.title("SAT participation rate VS ACT participation rate")
plt.ylabel("ACT Participation rate", fontsize = 20)
plt.xlabel("SAT Participation rate", fontsize = 20);

# %%
#finding correlation between SAT participation rate and ACT participation rate
np.corrcoef(sat_2019['participation_rate'],act_2019['participation_rate'])
# Out:
# array([[ 1.       , -0.8654353],
#        [-0.8654353,  1.       ]])

# %%
# Establish the size of the figure.
plt.figure(figsize = (16, 9))

# Create scatterplot of sat participation vs act participation
plt.scatter(sat_college_major_2019['participation_rate'],
            sat_college_major_2019['total_score']);

plt.title("SAT by Intended College Major participation rate VS SAT by Intended College Major total Score")
plt.ylabel("SAT by Intended College Major Participation rate", fontsize = 20)
plt.xlabel("SAT by Intended College Major Total Score", fontsize = 20);

# %%
#finding correlation between SAT test takers and total_scores for Intended college major
np.corrcoef(sat_college_major_2019['testtakers'],sat_college_major_2019['total_score'])
# Out:
# array([[1.        , 0.14541292],
#        [0.14541292, 1.        ]])

# %%
# Establish the size of the figure.
plt.figure(figsize = (16, 9))

# Create scatterplot of sat participation vs act participation
plt.scatter(sat_college_major_2019['testtakers'],
            sat_college_major_2019['total_score']);

plt.title("SAT by Intended College Major number of Test takers VS SAT by Intended College Major total Score")
plt.ylabel("SAT by Intended College Major Test Takers", fontsize = 20)
plt.xlabel("SAT by Intended College Major Total Score", fontsize = 20);

# %% [markdown]
# ### Plotting bar graphs for SAT scores by Intended College Major

# %%
#sorting highest participation rate for each intended college major to lowest
df1 = sat_college_major_2019.sort_values(by=['testtakers'],ascending=[False])

# %%
plt.figure(figsize=(10,15))
sns.barplot('participation_rate', 'intendedcollegemajor', data = df1)
plt.title('SAT Participation rate for each college major') 
plt.ylabel('Intended College Major')
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Intended College Major')

# %%
#sorting highest participation rate for each intended college major to lowest
df3 = act_college_major_2019.sort_values(by=['testtakers'],ascending=[False])

# %%
plt.figure(figsize=(10,15))
sns.barplot('participation_rate', 'intendedcollegemajor', data = df3)
plt.title('ACT Participation rate for each college major') 
plt.ylabel('Intended College Major')
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Intended College Major')

# %%
#sorting highest total score for the intended college major
df2= sat_college_major_2019.sort_values(by=['total_score'],ascending=[False])

# %%
plt.figure(figsize=(10,15))
sns.barplot('total_score', 'intendedcollegemajor', data = df2)
plt.title('SAT Total Score for each college major') 
plt.ylabel('Intended College Major')
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Intended College Major')

# %%
#using sorted high participation rate/number of test takers per college major, plot with EBRW

plt.figure(figsize=(10,15))
sns.barplot('ebrw','intendedcollegemajor', data = df1)
plt.title('EBRW scores for each college major SAT') 
plt.ylabel('Intended College Major')
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Intended College Major')

# %%
#using sorted high participation rate/number of test takers per college major, plot with Math
plt.figure(figsize=(10,15))
sns.barplot('math', 'intendedcollegemajor', data = df1)
plt.title('Math scores for each college major SAT') 
plt.ylabel('Intended College Major')
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Intended College Major')

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# To present recommendations to the US Department of Education on how to improve overall SAT and ACT participation rates by studying underlying factors in different States, Races, College Majors, Income Background, and School Subsidies.
#
# In order to increase the participation rate for SAT, we will see if there are any underlying factors that may contribute to the increase in SAT participation across states.
#
# From data comparison between SAT and ACT, ACT has higher participation rate compared to SAT in 2019. From the SAT scores by Intended College Major data, the top few most participated college majors are: health professions, clinical sciences, business, engineering and visual performing arts. This might be due to underlying reasons such as: better career prospects and better salary.
#
# There were pretty large number of test takers who are undecided as to which college major that they would like to choose from. Also, there were very little participating rate for college majors such as mechanic, culinary services, construction trades, transportation, librarianship. This might be due to the nature of these jobscope that do not really require a college degree or their median salary is not high compared to other college majors that can result in a higher paying job in the future.
#
# There is not much correlation as to how Intended College majors will be able to increase participation rate for SAT or ACT. One area that can be improved on is to provide necessary support to students prior to taking the SAT or ACT test so that they are able to realise areas or fields that they are interested in or that they are excellent at. This is to minimise the repurcussions in the future where students are not inspired to take SAT/ACT as they have not yet decide on which College Majors that they intend to pursue in. Another area that can be improved is to have more emphasis in inclusion of science in the SAT test as one of the highest SAT participation rate is for Science based as the intended college major. This is also true for the data from ACT participation rate by Intended College Major. As ACT test has a component on Science, by having more emphasis on Science in SAT as well will ensure that students who wants to major in Science will feel more ready to further in it in college.
